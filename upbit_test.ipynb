# %%
import pyupbit
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

price = pyupbit.get_current_price("KRW-BTC")
print(price)
# Out:
# 139397000.0

# %%
minute1 = pyupbit.get_ohlcv("KRW-BTC", "minute1")
minute1
# Out:
#                             open         high          low        close  \
# 2025-01-01 15:21:00  140173000.0  140173000.0  140090000.0  140170000.0
# 2025-01-01 15:22:00  140170000.0  140170000.0  140096000.0  140169000.0
# 2025-01-01 15:23:00  140169000.0  140170000.0  140104000.0  140169000.0
# 2025-01-01 15:24:00  140166000.0  140214000.0  140097000.0  140214000.0
# 2025-01-01 15:25:00  140214000.0  140216000.0  140090000.0  140169000.0
# ...                          ...          ...          ...          ...
# 2025-01-01 18:36:00  139681000.0  139685000.0  139599000.0  139600000.0
# 2025-01-01 18:37:00  139600000.0  139600000.0  139414000.0  139414000.0
# 2025-01-01 18:38:00  139414000.0  139414000.0  139302000.0  139367000.0
# 2025-01-01 18:39:00  139397000.0  139397000.0  139268000.0  139397000.0
# 2025-01-01 18:40:00  139397000.0  139400000.0  139327000.0  139397000.0
#
#                        volume         value
# 2025-01-01 15:21:00  0.141713  1.986215e+07
# 2025-01-01 15:22:00  0.562493  7.881002e+07
# 2025-01-01 15:23:00  0.408350  5.721995e+07
# 2025-01-01 15:24:00  1.749006  2.451277e+08
# 2025-01-01 15:25:00  0.855988  1.199429e+08
# ...                       ...           ...
# 2025-01-01 18:36:00  1.676036  2.340192e+08
# 2025-01-01 18:37:00  1.041863  1.453769e+08
# 2025-01-01 18:38:00  0.858867  1.197169e+08
# 2025-01-01 18:39:00  2.898564  4.038777e+08
# 2025-01-01 18:40:00  0.475028  6.620117e+07
#
# [200 rows x 6 columns]

# %%
minute1.plot()
# Out:
# <Axes: >

# %%
import mplfinance as mpf
mpf.plot(minute1, type='candle', style='charles', volume=True, mav=(5, 10, 60))

# %%
pyupbit.get_current_price("KRW-BTC")
# Out:
# 139998000.0
